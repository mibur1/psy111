# %% [markdown]
# # 1.3 Exercises

# %% [markdown]
# Course contents that require interactive coding blocks can be implemented in .ipynb files. These files can be opened and used locally or in google colab by clicking on the Rocket icon in the top right corner of the book.

# %% [markdown]
# ## Python code chunks
#
# Let's start with importing the required libraries:

# %%
import numpy as np                     # library for numerical calculations
from matplotlib import pyplot as plt    # library for plotting
# %matplotlib inline

# %% [markdown]
# Now, lets plot a 3-dimensional stem plot. We first create separate data points for the x, y, and z coordinates and thenn pass these variables to the ```ax.stem()``` function:

# %%
plt.style.use('_mpl-gallery')

# Make data
n = 20
x = np.sin(np.linspace(0, 2*np.pi, n))
y = np.cos(np.linspace(0, 2*np.pi, n))
z = np.linspace(0, 1, n)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.stem(x, y, z)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[]);
plt.show() # When using %matplotlib inline, plt.show() is not necessary
